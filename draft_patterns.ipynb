# %%
from patterns.porcupine_tree import PorcupineTree

pattern = PorcupineTree.the_sound_of_the_muzak()
pattern
# Out:
# [BPM] 90
# [note_division] 4
# 1000 1000 1000 1000 1000 1000 1000 | hihat_closed
# 0000 0100 0000 1000 0001 0000 0010 | snare
# 1001 0001 0010 0010 0100 0100 1000 | kick
